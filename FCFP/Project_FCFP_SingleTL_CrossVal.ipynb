# %% [markdown]
# ## Single Task Learning prediction for kinases with data from ChEMBL - FCFP version
# This notebook evaluates and compares the performance of three regressors, Random Forests, Neural Networks, and Lasso Regression, all implemented by Scikit-learn for predicting bioactivity values. We are using pIC50 values on a dataset with 110 targets. As we are not interested for optimisation at this point, we run just a quick parameter selection through a 4-fold cross-validation.

# %% [markdown]
# ## 0. Prerequisites

# %%
import numpy as np
import pandas as pd
import keras, os, pickle

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor

from keras.models import Sequential
from keras.layers import Dense
from keras import regularizers
from keras.wrappers.scikit_learn import KerasRegressor # this is for making a model like every other in scikit
from keras.models import load_model, model_from_json

import  matplotlib.pyplot as plt
from time import time

np.random.seed(42)
from tensorflow import set_random_seed
set_random_seed(42)

nfolds=4; njobs =3
pathtosaved = 'TrainedModels/'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Split to Train-Validation sets

# %%
Interactions_train = []    
with open("../Interactions_Trainset.tab",'r') as f:
    for line in f:
        tokens = line.split()
        # 'Target-ID', 'Compound-ID', 'pIC50'  
        Interactions_train.append( [tokens[0], tokens[1], float(tokens[2]) ])

Interactions_valid = []        
with open("../Interactions_Validset.tab",'r') as f:
    for line in f:
        tokens = line.split()
        # 'Target-ID', 'Compound-ID', 'pIC50'  
        Interactions_valid.append( [tokens[0], tokens[1], float(tokens[2]) ])

Interactions = [x for x in Interactions_train]
Interactions.extend(Interactions_valid)
print("Basic stats about whole - train - validation sets:")
print( np.mean([x[2] for x in Interactions]), '\t', np.mean([x[2] for x in Interactions_valid]), '\t', np.mean([x[2] for x in Interactions_train]) )
print( np.std([x[2] for x in Interactions]) , '\t', np.std([x[2] for x in Interactions_valid]) , '\t', np.std([x[2] for x in Interactions_train])  )
# Out:
# Basic stats about whole - train - validation sets:
# 4.395417284295644 	 4.402954075633978 	 4.393533169991576
# 2.588704763200101 	 2.5731665596073765 	 2.5925711685326958

# %%
plt.hist([t[2] for t in Interactions], bins=20, rwidth=0.90)
plt.xlabel('pIC50 values', fontsize=13)
plt.ylabel('Count',fontsize=13)
# plt.savefig("TrueDistr.png")
plt.show()

# %%
# we use a dataframe to quickly sort targets wrt #compounds:
DF = pd.DataFrame( Interactions, columns =['Target-ID', 'Compound-ID','Std-value']) 
temp = DF.groupby(['Target-ID']).agg('count').sort_values(by='Compound-ID') # count the number of molecules
Targets = list(temp.index)
Compounds = np.unique(DF['Compound-ID'])

nT=len(Targets); nC=len(Compounds)

print("There are {0} targets and {1} compounds currently loaded with {2} interactions.".format(nT,nC,len(Interactions)))
print("A DTI matrix would be {0:.4}% dense!".format(100.0*len(Interactions)/nT/nC ))

# first we need to prepare each fp as a feature vector
Fingerprints={} # this contains one list per fingerprint - not efficient...
with open('Compound_Fingerprints_FCFP.tab', 'r') as f:
    header = f.readline()
    for line in f:
        # each line is Comp-ID, SMILES, FP
        tokens = line.split()
        # we keep only those compounds which have FPs
        if tokens[2] != 'NOFP':
            fp = [int(c) for c in tokens[2] ]
            Fingerprints[ tokens[0] ] = fp
print("%d fingerprints were loaded!" % len(Fingerprints))
del temp, DF, Interactions
# Out:
# There are 110 targets and 23167 compounds currently loaded with 56392 interactions.
# A DTI matrix would be 2.213% dense!
# 155083 fingerprints were loaded!

# %% [markdown]
# ## 1. Random Forests

# %%
Target_info = {} # this is a "global" variable

RF_all = dict()
Scores_RF_train=[]
count=0
param_grid={'n_estimators':[10,25,50,100,150], 'max_depth':[3,4,5,7,10,15,20], 'max_features':['sqrt','auto']}
for target in Targets:
    Target_info[target] = {}
    # define the train set
    X_train=[]; Y_train=[]
    for point in Interactions_train:
        if point[0]==target:
            X_train.append( Fingerprints[point[1]] )
            Y_train.append( float(point[2]) )
    Target_info[target]['train_size']=len(Y_train) # add info
    if len(Y_train)>40:
        if os.path.isfile(pathtosaved+'RF_'+target+'_'+'pIC50_FCFP.sav'):
            # model is already trained - just load
            with open( pathtosaved+'RF_'+target+'_'+'pIC50_FCFP.sav', 'rb') as f:
                RFR = pickle.load( f )
        else:
            print("training...")
            # we need to ensure there is enough data for CV
            cvr = GridSearchCV(RandomForestRegressor(random_state=2019), param_grid, cv=nfolds, n_jobs=njobs, iid=True)
            # here comes the long step
            cvr.fit(X_train, Y_train)
            # select best parametrisation and train to the complete train-set
            RFR = RandomForestRegressor( n_estimators= cvr.best_params_['n_estimators'],max_features=cvr.best_params_['max_features'], max_depth=cvr.best_params_['max_depth'], random_state=2019)
            RFR.fit(X_train,Y_train)
            # save model
            pickle.dump(RFR, open(pathtosaved+'RF_'+target+'_'+'pIC50_FCFP.sav', 'wb'))
        RF_all[target] = RFR
        Scores_RF_train.append( RFR.score( X_train,  Y_train))
        Target_info[target]['RF_train_r2'] = Scores_RF_train[-1] # add info
#         print(Scores_RFR_train[-1])
    else:
        print("Not enough data for %s" % target)
    if count%25==0:
        print("More than %d targets are processed" % count)
        print("Mean score so far: %f" % np.mean(Scores_RF_train))
    count+=1
    
print("Mean score for RF during training = %f" % np.mean(Scores_RF_train) )
# Out:
# training...
# More than 0 targets are processed
# Mean score so far: 0.916309
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# More than 25 targets are processed
# Mean score so far: 0.897111
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# More than 50 targets are processed
# Mean score so far: 0.897276
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# More than 75 targets are processed
# Mean score so far: 0.899242
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# More than 100 targets are processed
# Mean score so far: 0.893260
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# training...
# Mean score for RF during training = 0.892098

# %% [markdown]
# ## 2. Neural Networks

# %%
NN_all = dict()
Scores_NN_train=[]
param_grid={'hidden_layer_sizes':[(50),(100,20),(100,50),(500,20,10)] }
count=0
for target in Targets:
    # define the train set
    X_train=[]; Y_train=[]
    for point in Interactions_train:
        if point[0]==target:
            X_train.append( Fingerprints[point[1]] )
            Y_train.append( float(point[2]) )
    if os.path.isfile(pathtosaved+'NN_'+target+'_'+'pIC50_FCFP.sav'):
        # model is already trained - just load
        with open( pathtosaved+'NN_'+target+'_'+'pIC50_FCFP.sav', 'rb') as f:
            MLPR = pickle.load( f )
    else:
        # we need to ensure there is enough data for CV
        cvr = GridSearchCV(MLPRegressor(activation='tanh', solver='lbfgs', random_state=2019), param_grid, cv=nfolds, n_jobs=njobs, iid=True)
        cvr.fit(X_train, Y_train)
        # select best parametrisation and train to the complete train-set
        MLPR = MLPRegressor( hidden_layer_sizes = cvr.best_params_['hidden_layer_sizes'], activation='tanh', solver='lbfgs', random_state=2019)
        MLPR.fit(X_train,Y_train)
        pickle.dump(MLPR, open(pathtosaved+'NN_'+target+'_'+'pIC50_FCFP.sav', 'wb'))
    NN_all[target] = MLPR
    Scores_NN_train.append( MLPR.score( X_train,  Y_train))
    Target_info[target]['NN_train_r2'] = Scores_NN_train[-1] # add info
    if count%25==0:
        print("More than %d targets are processed" % count)
        print("Mean score so far: %f" % np.mean(Scores_NN_train))
    count+=1
    
print("Mean score for NN during training = %f" % np.mean(Scores_NN_train))
# Out:
# More than 0 targets are processed
# Mean score so far: 0.999993
# More than 25 targets are processed
# Mean score so far: 0.990042
# More than 50 targets are processed
# Mean score so far: 0.987537
# More than 75 targets are processed
# Mean score so far: 0.987787
# More than 100 targets are processed
# Mean score so far: 0.985809
# Mean score for NN during training = 0.984689

# %% [markdown]
# ## 3. Lasso Regression

# %%
from sklearn.linear_model import Lasso

LR_all = dict()
Scores_LR_train=[]
param_grid={'alpha':[1, 0.5, 0.1, 0.01]}
count=0
for target in Targets:
    # define the train set
    X_train=[]; Y_train=[]
    for point in Interactions_train:
        if point[0]==target:
            X_train.append( Fingerprints[point[1]] )
            Y_train.append( float(point[2]) )
    
    if os.path.isfile(pathtosaved+'LR_'+target+'_'+'pIC50_FCFP.sav'):
        # model is already trained - just load
        with open( pathtosaved+'LR_'+target+'_'+'pIC50_FCFP.sav', 'rb') as f:
            LR = pickle.load( f )
    else:
        print("cross validation")
        cvr = GridSearchCV(Lasso(random_state=2019, max_iter=3000), param_grid, cv=nfolds, n_jobs=njobs, iid=True)
        cvr.fit(X_train, Y_train)
        # select best parametrisation
        LR = Lasso( alpha= cvr.best_params_['alpha'], max_iter=3000, random_state=2019)
        LR.fit(X_train,Y_train)
        pickle.dump(LR, open(pathtosaved+'LR_'+target+'_'+'pIC50_FCFP.sav', 'wb'))
        
    Scores_LR_train.append( LR.score( X_train,  Y_train))
    Target_info[target]['LR_train_r2'] = Scores_LR_train[-1] # add info
    LR_all[target] = LR
    if count%25==0:
        print("More than %d targets are processed" % count)
        print("Mean score so far: %f" % np.mean(Scores_LR_train))
    count+=1 

print("Mean score for LR during training = %f" % np.mean(Scores_LR_train) )
# Out:
# cross validation
# More than 0 targets are processed
# Mean score so far: 0.958469
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# More than 25 targets are processed
# Mean score so far: 0.820189
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# More than 50 targets are processed
# Mean score so far: 0.784204
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# More than 75 targets are processed
# Mean score so far: 0.771589
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# More than 100 targets are processed
# Mean score so far: 0.748184
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# cross validation
# Mean score for LR during training = 0.738392

# %% [markdown]
# ## 4. Personalised NN with Keras

# %%
myNN_all = dict()
Scores_myNN_train=[]
param_grid={'lamda':[0.2, 0.1, 0.01, 0.001]}
count=0

def mymodel(lamda, init=4.5):
    model = Sequential()

    model.add(Dense(units=100, activation='relu', kernel_regularizer=regularizers.l2(lamda), input_dim=2048))
    model.add(Dense(units=20,  activation='relu', kernel_regularizer=regularizers.l2(lamda), input_dim=100 ))
    myinit = keras.initializers.Constant(value=init)
    model.add(Dense(1, kernel_initializer=myinit, activity_regularizer=regularizers.l1(0.001)))
    
    model.compile(loss='mean_squared_error', optimizer=keras.optimizers.adam(lr=0.001))
    return model

for target in Targets:
    # define the train set
    X_train=[]; Y_train=[]
    for point in Interactions_train:
        if point[0]==target:
            X_train.append( Fingerprints[point[1]] )
            Y_train.append( float(point[2]) )
        
    X_train = np.array( X_train )

    if os.path.isfile(pathtosaved+'Keras/Keras_'+target+'_'+'pIC50model.json'):
        # model is already trained for current target
        with open( pathtosaved+'Keras/Keras_'+target+'_'+'pIC50model.json', 'r') as jsonf:
            json_model = jsonf.read()
        myNN = model_from_json(json_model)
        myNN.load_weights( pathtosaved+'Keras/Keras_'+target+'_'+'weights.h5'  )
        myNN.compile(loss='mean_squared_error', optimizer=keras.optimizers.adam(lr=0.001))
#         myNN.fit(X_train,Y_train, epochs=250, batch_size=20, verbose=0)
    else:
        print("training for", target)
        myNN = KerasRegressor(build_fn=mymodel, init=4.5, epochs=250, batch_size=20, verbose=0)
        # fit model to data:
        cvr = GridSearchCV(myNN, param_grid=param_grid, cv=nfolds, n_jobs=njobs, iid=True)
        cvr.fit(X_train, Y_train)
        myNN = KerasRegressor(build_fn=mymodel, init=4.5, lamda=cvr.best_params_['lamda'], epochs=250, batch_size=20, verbose=0)
        myNN.fit(X_train,Y_train)
        # save:
        model_json=myNN.model.to_json()
        with open( pathtosaved+'Keras/Keras_'+target+'_'+'pIC50model.json', 'w') as jsonf:
            jsonf.write(model_json)
        myNN.model.save_weights( pathtosaved+'/Keras/Keras_'+target+'_'+'weights.h5' )
    Y_NN = myNN.predict(X_train)
    # get scores and details:
    Scores_myNN_train.append( r2_score(Y_train, Y_NN) )
    Target_info[target]['my_train_r2'] = Scores_myNN_train[-1] # add info
    myNN_all[target] = myNN # save model for validation
    if count%20==0:
        print("More than %d targets are processed" % count)
        print("Mean score so far: %f" % np.mean(Scores_myNN_train))
    count+=1
    
print("Mean score for myNN during training = %f" % np.mean(Scores_myNN_train) )
# Out:
# training for CHEMBL5122
# WARNING:tensorflow:From /homes/kalantzi/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /homes/kalantzi/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /homes/kalantzi/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /homes/kalantzi/.local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /homes/kalantzi/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /homes/kalantzi/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# More than 0 targets are processed
# Mean score so far: 0.997622
# training for CHEMBL2095942
# training for CHEMBL3116
# training for CHEMBL3430907
# training for CHEMBL4203
# training for CHEMBL3797
# training for CHEMBL2208
# training for CHEMBL2111414
# training for CHEMBL1906
# training for CHEMBL3961
# training for CHEMBL4070
# training for CHEMBL4036
# training for CHEMBL3983
# training for CHEMBL4040
# training for CHEMBL4898
# training for CHEMBL3024
# training for CHEMBL2095227
# training for CHEMBL4376
# training for CHEMBL2094115
# training for CHEMBL3231
# training for CHEMBL2094138
# More than 20 targets are processed
# Mean score so far: 0.983467
# training for CHEMBL3009
# training for CHEMBL2095217
# training for CHEMBL5570
# training for CHEMBL5314
# training for CHEMBL5491
# training for CHEMBL3629
# training for CHEMBL5331
# training for CHEMBL2850
# training for CHEMBL2095188
# training for CHEMBL5508
# training for CHEMBL4816
# training for CHEMBL4895
# training for CHEMBL4937
# training for CHEMBL3616
# training for CHEMBL3905
# training for CHEMBL2959
# training for CHEMBL2599
# training for CHEMBL2749
# training for CHEMBL3476
# training for CHEMBL2041
# More than 40 targets are processed
# Mean score so far: 0.978276
# training for CHEMBL3582
# training for CHEMBL3038469
# training for CHEMBL2828
# training for CHEMBL4224
# training for CHEMBL1991
# training for CHEMBL4439
# training for CHEMBL3142
# training for CHEMBL5543
# training for CHEMBL2508
# training for CHEMBL1955
# training for CHEMBL4630
# training for CHEMBL1907602
# training for CHEMBL1907605
# training for CHEMBL2842
# training for CHEMBL2094127
# training for CHEMBL3234
# training for CHEMBL2007
# training for CHEMBL2068
# training for CHEMBL299
# training for CHEMBL3529
# More than 60 targets are processed
# Mean score so far: 0.977433
# training for CHEMBL2996
# training for CHEMBL2292
# training for CHEMBL3920
# training for CHEMBL5408
# training for CHEMBL2815
# training for CHEMBL4247
# training for CHEMBL1907600
# training for CHEMBL2363049
# training for CHEMBL2695
# training for CHEMBL2094126
# training for CHEMBL331
# training for CHEMBL3717
# training for CHEMBL2637
# training for CHEMBL4179
# training for CHEMBL1862
# training for CHEMBL5147
# training for CHEMBL1844
# training for CHEMBL2094128
# training for CHEMBL2276
# training for CHEMBL1957
# More than 80 targets are processed
# Mean score so far: 0.977026
# training for CHEMBL1907601
# training for CHEMBL308
# training for CHEMBL1913
# training for CHEMBL2431
# training for CHEMBL258
# training for CHEMBL3973
# training for CHEMBL1868
# training for CHEMBL5407
# training for CHEMBL4142
# training for CHEMBL1981
# training for CHEMBL1936
# training for CHEMBL2358
# training for CHEMBL3038477
# training for CHEMBL4501
# training for CHEMBL3553
# training for CHEMBL260
# training for CHEMBL301
# training for CHEMBL1974
# training for CHEMBL2185
# training for CHEMBL4282
# More than 100 targets are processed
# Mean score so far: 0.974414
# training for CHEMBL3650
# training for CHEMBL4722
# training for CHEMBL4523
# training for CHEMBL1824
# training for CHEMBL2147
# training for CHEMBL2148
# training for CHEMBL2971
# training for CHEMBL203
# training for CHEMBL279
# Mean score for myNN during training = 0.973869

# %% [markdown]
# ## 5. Evaluation

# %%
Pred_NN = []; Pred_RF  = []; Pred_LR = []; Pred_my=[];
True_vals = []
Pred_pertarget = dict() # contains lists with tuples: (true, pred_RF, pred_NN)

Time_RF=0; Time_NN=0; Time_LR=0; Time_my=0
with open("SingleTL_FCFP_results.txt",'w') as f:
#     this file contains all the important stuff for the comparison
    f.write("Target\tCompound\tTrue\tRFR\tMLPR\tLR\tKeras\n")
    for point in Interactions_valid:
        # point = [ target, compound, pIC50 ]
        True_vals.append( float(point[2]) )
        x_test = np.array( Fingerprints[point[1]] ).reshape(1,-1) # prepare for prediction
        
        t0=time()
        model = RF_all[point[0]]
        Pred_RF.append( model.predict( x_test ) )
        Time_RF+=time()-t0
        
        t0=time()
        model = NN_all[point[0]]
        Pred_NN.append( model.predict( x_test ) )
        Time_NN+=time()-t0
        
        t0=time()
        model = LR_all[point[0]]
        Pred_LR.append( model.predict( x_test ) )
        Time_LR+=time()-t0
        
        t0=time()
        model = myNN_all[point[0]]
        Pred_my.append( model.predict( x_test ) )
        Time_my+=time()-t0
        
        f.write("{0}\t{1}\t{2}\t{3}\t{4}\t{5}\t{6}\n".format(point[0], point[1], point[2], Pred_RF[-1][0], Pred_NN[-1][0], Pred_LR[-1][0], Pred_my[-1][0]))

        if point[0] in Pred_pertarget:
            Pred_pertarget[point[0]].append( (True_vals[-1], Pred_RF[-1][0], Pred_NN[-1][0], Pred_LR[-1][0], Pred_my[-1][0])  )
        else:
            # first time for this protein
            Pred_pertarget[point[0]] = [ (True_vals[-1], Pred_RF[-1][0], Pred_NN[-1][0], Pred_LR[-1][0], Pred_my[-1][0]) ]
        
print("Performance for RF = %f" % r2_score( True_vals, Pred_RF ))
print("Performance for NN = %f" % r2_score( True_vals, Pred_NN ))
print("Performance for LR = %f" % r2_score( True_vals, Pred_LR ))
print("Performance for Keras = %f" % r2_score( True_vals, Pred_my ))
# Out:
# Performance for RF = 0.648015
# Performance for NN = 0.547091
# Performance for LR = 0.585172
# Performance for Keras = 0.624789

# %%
print("RF: Duration per 1000 predictions = {0}".format(1000*Time_RF/len(Interactions_valid) ))
print("LR: Duration per 1000 predictions = {0}".format(1000*Time_LR/len(Interactions_valid) ))
print("NN: Duration per 1000 predictions = {0}".format(1000*Time_NN/len(Interactions_valid) ))
print("my: Duration per 1000 predictions = {0}".format(1000*Time_my/len(Interactions_valid) ))
# Out:
# RF: Duration per 1000 predictions = 7.087809478460759
# LR: Duration per 1000 predictions = 0.07871614108801861
# NN: Duration per 1000 predictions = 0.3687406520637178
# my: Duration per 1000 predictions = 4.68295929934628

# %%
trf = 1000*Time_RF/len(Interactions_valid); tlr = 1000*Time_LR/len(Interactions_valid)
tnn = 1000*Time_NN/len(Interactions_valid); tmy = 1000*Time_my/len(Interactions_valid)
tmt = 0.3734; tdr = 1.2
print("RF: Duration per 1000 predictions = {0}".format( trf/tmt ))
print("LR: Duration per 1000 predictions = {0}".format( tlr/tmt ))
print("NN: Duration per 1000 predictions = {0}".format( tnn/tmt ))
print("my: Duration per 1000 predictions = {0}".format( tmy/tmt ))
# Out:
# RF: Duration per 1000 predictions = 18.98181435045731
# LR: Duration per 1000 predictions = 0.21080916199255118
# NN: Duration per 1000 predictions = 0.9875218319863894
# my: Duration per 1000 predictions = 12.541401444419602

# %%
Scores_RF_valid_pertarget = []
Scores_NN_valid_pertarget = []
Scores_LR_valid_pertarget = []
Scores_my_valid_pertarget = []

for target in Pred_pertarget:
    true=[]
    pred_RF=[]; pred_NN=[]; pred_LR=[]; pred_my =[] # temp variables
    # aggregate predictions
    for point in Pred_pertarget[target]:
        true.append( point[0] )
        pred_RF.append( point[1] )
        pred_NN.append( point[2] )
        pred_LR.append( point[3] )
        pred_my.append( point[4] )
    Target_info[target]['test_size']=len(true) # add info
    
    # calculate performance for each method
    r2 = r2_score(true, pred_RF)
    Target_info[target]['RF_valid_r2'] = r2 # add info
    Scores_RF_valid_pertarget.append( r2 )
    
    r2 = r2_score(true, pred_NN)
    Target_info[target]['NN_valid_r2'] = r2 # add info
    Scores_NN_valid_pertarget.append( r2 )

    r2 = r2_score(true, pred_LR)
    Target_info[target]['LR_valid_r2'] = r2 # add info
    Scores_LR_valid_pertarget.append( r2 )
    
    r2 = r2_score(true, pred_my)
    Target_info[target]['my_valid_r2'] = r2 # add info
    Scores_my_valid_pertarget.append( r2 )

    print("R2 score for {0}, RF | NN | LR | Keras = {1:.2f} | {2:.2f} | {3:.2f} | {4:.3f}".format(target, Scores_RF_valid_pertarget[-1], Scores_NN_valid_pertarget[-1], Scores_LR_valid_pertarget[-1], Scores_my_valid_pertarget[-1]))
# Out:
# R2 score for CHEMBL260, RF | NN | LR | Keras = 0.65 | 0.27 | 0.58 | 0.581
# R2 score for CHEMBL4722, RF | NN | LR | Keras = 0.68 | 0.50 | 0.59 | 0.588
# R2 score for CHEMBL2695, RF | NN | LR | Keras = 0.57 | 0.46 | 0.62 | 0.554
# R2 score for CHEMBL3038477, RF | NN | LR | Keras = 0.43 | 0.18 | 0.38 | 0.353
# R2 score for CHEMBL2996, RF | NN | LR | Keras = 0.46 | 0.30 | 0.45 | 0.482
# R2 score for CHEMBL2148, RF | NN | LR | Keras = 0.74 | 0.72 | 0.66 | 0.709
# R2 score for CHEMBL2147, RF | NN | LR | Keras = 0.68 | 0.62 | 0.63 | 0.661
# R2 score for CHEMBL5147, RF | NN | LR | Keras = 0.40 | 0.25 | 0.36 | 0.250
# R2 score for CHEMBL308, RF | NN | LR | Keras = 0.51 | 0.45 | 0.42 | 0.556
# R2 score for CHEMBL3234, RF | NN | LR | Keras = 0.57 | 0.47 | 0.35 | 0.588
# R2 score for CHEMBL4523, RF | NN | LR | Keras = 0.64 | 0.60 | 0.55 | 0.631
# R2 score for CHEMBL2358, RF | NN | LR | Keras = 0.32 | 0.04 | 0.25 | 0.198
# R2 score for CHEMBL1936, RF | NN | LR | Keras = 0.44 | 0.28 | 0.27 | 0.316
# R2 score for CHEMBL3629, RF | NN | LR | Keras = 0.52 | 0.53 | 0.58 | 0.485
# R2 score for CHEMBL279, RF | NN | LR | Keras = 0.53 | 0.35 | 0.38 | 0.462
# R2 score for CHEMBL1824, RF | NN | LR | Keras = 0.58 | 0.49 | 0.43 | 0.588
# R2 score for CHEMBL203, RF | NN | LR | Keras = 0.57 | 0.42 | 0.44 | 0.557
# R2 score for CHEMBL1862, RF | NN | LR | Keras = 0.65 | 0.55 | 0.62 | 0.653
# R2 score for CHEMBL3553, RF | NN | LR | Keras = 0.57 | 0.59 | 0.49 | 0.630
# R2 score for CHEMBL3529, RF | NN | LR | Keras = 0.54 | 0.42 | 0.50 | 0.577
# R2 score for CHEMBL299, RF | NN | LR | Keras = 0.82 | 0.81 | 0.79 | 0.822
# R2 score for CHEMBL4040, RF | NN | LR | Keras = 0.37 | 0.39 | 0.47 | 0.392
# R2 score for CHEMBL2828, RF | NN | LR | Keras = 0.81 | 0.71 | 0.81 | 0.766
# R2 score for CHEMBL2599, RF | NN | LR | Keras = 0.64 | 0.61 | 0.56 | 0.524
# R2 score for CHEMBL3973, RF | NN | LR | Keras = 0.65 | 0.45 | 0.52 | 0.532
# R2 score for CHEMBL1957, RF | NN | LR | Keras = 0.64 | 0.47 | 0.69 | 0.641
# R2 score for CHEMBL2095942, RF | NN | LR | Keras = 0.30 | 0.37 | 0.30 | 0.544
# R2 score for CHEMBL2185, RF | NN | LR | Keras = 0.60 | 0.38 | 0.48 | 0.551
# R2 score for CHEMBL2094126, RF | NN | LR | Keras = 0.39 | 0.10 | 0.42 | 0.289
# R2 score for CHEMBL2959, RF | NN | LR | Keras = 0.76 | 0.78 | 0.66 | 0.792
# R2 score for CHEMBL4630, RF | NN | LR | Keras = 0.31 | -0.21 | 0.27 | 0.214
# R2 score for CHEMBL1913, RF | NN | LR | Keras = 0.61 | 0.50 | 0.55 | 0.639
# R2 score for CHEMBL3920, RF | NN | LR | Keras = 0.55 | 0.32 | 0.51 | 0.496
# R2 score for CHEMBL1907601, RF | NN | LR | Keras = 0.66 | 0.67 | 0.68 | 0.729
# R2 score for CHEMBL1868, RF | NN | LR | Keras = 0.48 | 0.37 | 0.45 | 0.520
# R2 score for CHEMBL4376, RF | NN | LR | Keras = -0.31 | -0.47 | -0.12 | -0.304
# R2 score for CHEMBL1974, RF | NN | LR | Keras = 0.48 | 0.08 | 0.43 | 0.383
# R2 score for CHEMBL2842, RF | NN | LR | Keras = 0.45 | 0.42 | 0.40 | 0.441
# R2 score for CHEMBL3983, RF | NN | LR | Keras = 0.61 | 0.49 | 0.57 | 0.642
# R2 score for CHEMBL1981, RF | NN | LR | Keras = 0.64 | 0.56 | 0.63 | 0.609
# R2 score for CHEMBL2971, RF | NN | LR | Keras = 0.62 | 0.62 | 0.57 | 0.621
# R2 score for CHEMBL331, RF | NN | LR | Keras = 0.72 | 0.52 | 0.67 | 0.739
# R2 score for CHEMBL4439, RF | NN | LR | Keras = 0.71 | 0.64 | 0.71 | 0.709
# R2 score for CHEMBL3717, RF | NN | LR | Keras = 0.53 | 0.38 | 0.47 | 0.482
# R2 score for CHEMBL4224, RF | NN | LR | Keras = 0.40 | 0.32 | 0.20 | 0.466
# R2 score for CHEMBL4070, RF | NN | LR | Keras = 0.53 | 0.47 | 0.49 | 0.583
# R2 score for CHEMBL2637, RF | NN | LR | Keras = 0.54 | 0.39 | 0.50 | 0.481
# R2 score for CHEMBL2276, RF | NN | LR | Keras = 0.48 | 0.28 | 0.39 | 0.464
# R2 score for CHEMBL4282, RF | NN | LR | Keras = 0.59 | 0.51 | 0.48 | 0.617
# R2 score for CHEMBL2094138, RF | NN | LR | Keras = 0.38 | 0.48 | 0.40 | 0.373
# R2 score for CHEMBL301, RF | NN | LR | Keras = 0.58 | 0.50 | 0.53 | 0.552
# R2 score for CHEMBL3582, RF | NN | LR | Keras = 0.40 | 0.37 | 0.41 | 0.319
# R2 score for CHEMBL5408, RF | NN | LR | Keras = 0.22 | -0.09 | 0.16 | 0.261
# R2 score for CHEMBL1907600, RF | NN | LR | Keras = 0.54 | 0.32 | 0.45 | 0.554
# R2 score for CHEMBL1907605, RF | NN | LR | Keras = 0.34 | 0.22 | 0.33 | 0.316
# R2 score for CHEMBL5407, RF | NN | LR | Keras = 0.38 | 0.25 | 0.37 | 0.392
# R2 score for CHEMBL5543, RF | NN | LR | Keras = 0.46 | 0.26 | 0.45 | 0.467
# R2 score for CHEMBL4937, RF | NN | LR | Keras = 0.57 | 0.56 | 0.58 | 0.624
# R2 score for CHEMBL3476, RF | NN | LR | Keras = 0.71 | 0.61 | 0.56 | 0.757
# R2 score for CHEMBL2094127, RF | NN | LR | Keras = 0.23 | -0.07 | 0.22 | 0.101
# R2 score for CHEMBL5570, RF | NN | LR | Keras = 0.19 | -0.11 | -0.05 | 0.284
# R2 score for CHEMBL4895, RF | NN | LR | Keras = 0.35 | 0.53 | 0.07 | 0.711
# R2 score for CHEMBL2292, RF | NN | LR | Keras = 0.45 | 0.30 | 0.30 | 0.409
# R2 score for CHEMBL3650, RF | NN | LR | Keras = 0.67 | 0.55 | 0.58 | 0.635
# R2 score for CHEMBL2095217, RF | NN | LR | Keras = 0.49 | 0.69 | 0.47 | 0.495
# R2 score for CHEMBL3231, RF | NN | LR | Keras = 0.52 | 0.34 | 0.47 | 0.590
# R2 score for CHEMBL1906, RF | NN | LR | Keras = 0.16 | 0.26 | 0.22 | 0.363
# R2 score for CHEMBL1844, RF | NN | LR | Keras = 0.69 | 0.42 | 0.66 | 0.609
# R2 score for CHEMBL2363049, RF | NN | LR | Keras = 0.41 | 0.42 | 0.38 | 0.372
# R2 score for CHEMBL3616, RF | NN | LR | Keras = 0.04 | -0.51 | -0.06 | -0.164
# R2 score for CHEMBL4816, RF | NN | LR | Keras = 0.51 | 0.50 | 0.52 | 0.497
# R2 score for CHEMBL3038469, RF | NN | LR | Keras = 0.65 | 0.57 | 0.52 | 0.564
# R2 score for CHEMBL2068, RF | NN | LR | Keras = 0.65 | 0.40 | 0.55 | 0.516
# R2 score for CHEMBL2815, RF | NN | LR | Keras = 0.62 | 0.64 | 0.47 | 0.657
# R2 score for CHEMBL4247, RF | NN | LR | Keras = 0.54 | 0.44 | 0.53 | 0.435
# R2 score for CHEMBL2850, RF | NN | LR | Keras = 0.43 | -0.20 | 0.15 | 0.221
# R2 score for CHEMBL2094128, RF | NN | LR | Keras = 0.53 | 0.46 | 0.57 | 0.554
# R2 score for CHEMBL4179, RF | NN | LR | Keras = 0.38 | 0.22 | 0.47 | 0.311
# R2 score for CHEMBL4501, RF | NN | LR | Keras = 0.59 | 0.46 | 0.59 | 0.564
# R2 score for CHEMBL4142, RF | NN | LR | Keras = 0.53 | 0.52 | 0.50 | 0.586
# R2 score for CHEMBL2749, RF | NN | LR | Keras = 0.43 | 0.26 | 0.45 | 0.420
# R2 score for CHEMBL2431, RF | NN | LR | Keras = 0.66 | 0.56 | 0.59 | 0.605
# R2 score for CHEMBL3009, RF | NN | LR | Keras = 0.62 | 0.41 | 0.52 | 0.737
# R2 score for CHEMBL2095227, RF | NN | LR | Keras = 0.47 | -0.08 | 0.28 | 0.367
# R2 score for CHEMBL3142, RF | NN | LR | Keras = 0.37 | 0.38 | 0.38 | 0.364
# R2 score for CHEMBL2041, RF | NN | LR | Keras = 0.36 | 0.06 | -0.05 | 0.329
# R2 score for CHEMBL5331, RF | NN | LR | Keras = 0.43 | 0.52 | 0.46 | 0.602
# R2 score for CHEMBL1907602, RF | NN | LR | Keras = 0.45 | 0.51 | 0.36 | 0.566
# R2 score for CHEMBL2095188, RF | NN | LR | Keras = 0.46 | -0.09 | 0.21 | 0.204
# R2 score for CHEMBL2208, RF | NN | LR | Keras = 0.37 | 0.32 | 0.10 | 0.316
# R2 score for CHEMBL1955, RF | NN | LR | Keras = 0.53 | 0.17 | 0.48 | 0.375
# R2 score for CHEMBL3024, RF | NN | LR | Keras = 0.49 | 0.56 | 0.55 | 0.459
# R2 score for CHEMBL5508, RF | NN | LR | Keras = 0.30 | 0.20 | 0.41 | 0.266
# R2 score for CHEMBL2508, RF | NN | LR | Keras = 0.59 | 0.30 | 0.52 | 0.497
# R2 score for CHEMBL3905, RF | NN | LR | Keras = 0.42 | 0.22 | 0.21 | 0.295
# R2 score for CHEMBL3430907, RF | NN | LR | Keras = 0.69 | 0.51 | 0.61 | 0.619
# R2 score for CHEMBL258, RF | NN | LR | Keras = 0.62 | 0.49 | 0.52 | 0.621
# R2 score for CHEMBL4898, RF | NN | LR | Keras = 0.48 | 0.46 | 0.46 | 0.534
# R2 score for CHEMBL5491, RF | NN | LR | Keras = 0.56 | 0.30 | 0.51 | 0.327
# R2 score for CHEMBL4036, RF | NN | LR | Keras = 0.34 | 0.23 | 0.25 | 0.116
# R2 score for CHEMBL2111414, RF | NN | LR | Keras = 0.46 | 0.35 | 0.15 | 0.147
# R2 score for CHEMBL3797, RF | NN | LR | Keras = 0.99 | 0.99 | 0.99 | 0.986
# R2 score for CHEMBL3961, RF | NN | LR | Keras = 0.19 | 0.43 | 0.04 | 0.326
# R2 score for CHEMBL2094115, RF | NN | LR | Keras = 0.47 | 0.48 | 0.38 | 0.507
# R2 score for CHEMBL5314, RF | NN | LR | Keras = 0.16 | -0.06 | 0.01 | 0.024
# R2 score for CHEMBL1991, RF | NN | LR | Keras = 0.47 | 0.37 | 0.45 | 0.291
# R2 score for CHEMBL5122, RF | NN | LR | Keras = 0.44 | 0.29 | 0.37 | 0.365
# R2 score for CHEMBL2007, RF | NN | LR | Keras = 0.48 | 0.36 | 0.41 | 0.528
# R2 score for CHEMBL4203, RF | NN | LR | Keras = -0.55 | -0.86 | -0.11 | -0.729
# R2 score for CHEMBL3116, RF | NN | LR | Keras = 0.60 | 0.59 | 0.59 | 0.547

# %%
print("Mean per target R2-score for RF = {0:.4f} and std = {1:.4f}".format( np.mean(Scores_RF_valid_pertarget), np.std(Scores_RF_valid_pertarget) )) 
print("Mean per target R2-score for NN = {0:.4f} and std = {1:.4f}".format( np.mean(Scores_NN_valid_pertarget), np.std(Scores_NN_valid_pertarget) ))
print("Mean per target R2-score for LR = {0:.4f} and std = {1:.4f}".format( np.mean(Scores_LR_valid_pertarget), np.std(Scores_LR_valid_pertarget) ))
print("Mean per target R2-score for my = {0:.4f} and std = {1:.4f}".format( np.mean(Scores_my_valid_pertarget), np.std(Scores_my_valid_pertarget) ))
# Out:
# Mean per target R2-score for RF = 0.4929 and std = 0.1967
# Mean per target R2-score for NN = 0.3633 and std = 0.2685
# Mean per target R2-score for LR = 0.4324 and std = 0.1955
# Mean per target R2-score for my = 0.4667 and std = 0.2248

# %% [markdown]
# ## 6. Analysis and Plotting

# %%
plt.figure(figsize=(10,6))

Y = [Target_info[x]['RF_train_r2'] for x in Targets]
plt.plot(Y,'b', label='RF')
plt.axhline(np.mean(Y),color='b', linestyle='--', alpha=0.6)

Y = [Target_info[x]['NN_train_r2'] for x in Targets]
plt.plot(Y,'r', label='NN')
plt.axhline(np.mean(Y),color='r', linestyle='--', alpha=0.6)

Y = [Target_info[x]['LR_train_r2'] for x in Targets]
plt.plot(Y,'g', label='Lasso', alpha=0.4)
plt.axhline(np.mean(Y),color='g', linestyle='--', alpha=0.6)

Y = [Target_info[x]['my_train_r2'] for x in Targets]
plt.plot(Y,'m', label='Keras')
plt.axhline(np.mean(Y),color='m', linestyle='--', alpha=0.6)

Sizes = [Target_info[x]['train_size'] for x in Targets]
xi = [0,25,55,80,109]
plt.xticks(xi, [Sizes[t] for t in xi])
plt.xlabel('Size of train-set per protein',fontsize=16)
plt.ylabel("Accuracy in R2",fontsize=16)
# plt.xticks( x, rotation='vertical')
plt.legend(loc=4, fontsize=14)
# plt.title("Training Performance")
plt.savefig("Train-all_FCFP.png", transparent=True)
plt.show()

# %%
plt.figure(figsize=(10,6))

Y = [Target_info[x]['RF_valid_r2'] for x in Targets]
plt.plot(Y,'b', label='RF')
plt.axhline(np.mean(Y),color='b', linestyle='--', alpha=0.6)

Y = [Target_info[x]['NN_valid_r2'] for x in Targets]
plt.plot(Y,'r', label='NN')
plt.axhline(np.mean(Y),color='r', linestyle='--', alpha=0.6)

Y = [Target_info[x]['LR_valid_r2'] for x in Targets]
plt.plot(Y,'g', alpha=0.5, label='LR')
plt.axhline(np.mean(Y),color='g', linestyle='--', alpha=0.6)

Y = [Target_info[x]['my_valid_r2'] for x in Targets]
plt.plot(Y,'m', label='Keras')
plt.axhline(np.mean(Y),color='m', linestyle='--', alpha=0.6)

plt.legend(loc=4, fontsize=14)
Sizes = [Target_info[x]['test_size'] for x in Targets]
xi = [0,25,55,80,109]
plt.xticks(xi, [Sizes[t] for t in xi])
plt.xlabel('Size of valid-set per protein',fontsize=16)
plt.ylabel("Accuracy in R2",fontsize=16)
# plt.title("Validation Performance")
plt.savefig("Valid-all_FCFP.png", transparent=True)
plt.show()

# %% [markdown]
# ### Just a scatterplot for all three approaches

# %%
target = Targets[70]
true=[]
pred_RF=[]; pred_NN=[]; pred_LR=[]; pred_my=[];
# aggregate predictions
for tuples in Pred_pertarget[target]:
    true.append( tuples[0] )
    pred_RF.append( tuples[1] )
    pred_NN.append( tuples[2] )
    pred_LR.append( tuples[3] )
    pred_my.append( tuples[4] )
    
plt.figure()
plt.plot(true, pred_RF,'x',label='RF')
plt.plot(true, pred_NN,'r.',label='NN')
plt.plot(true, pred_LR,'g.',label='LR')
plt.plot(true, pred_my,'m.',label='Keras')
plt.plot([min(true), max(true)], [min(true), max(true)])
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ### How to get the dominant parametrisations

# %%
from scipy.stats import mode
temp1 = []; temp2=[]; temp3=[]; temp4=[]; temp5=[];
for model in LR_all:
    temp1.append( LR_all[model].get_params()['alpha'] )
    temp2.append( RF_all[model].get_params()['n_estimators'] )
    temp3.append( RF_all[model].get_params()['max_depth'] )
    temp4.append( NN_all[model].get_params()['hidden_layer_sizes'])
    temp5.append( myNN_all[model].get_params()['lamda'] )
print('LR - best alpha = {0} with {1}.'.format( mode(temp1)[0], mode(temp1)[1][0]) )
print('RF - best n-estimat = {0} with {1}.'.format( mode(temp2)[0], mode(temp2)[1][0]) )
print('RF - best max-depth = {0} with {1}.'.format( mode(temp3)[0], mode(temp3)[1][0]) )
print('Keras - best lamda = {0} with {1}'.format( mode(temp5)[0], mode(temp5)[1][0]) )
temp_dict={}
for x in temp4:
    if str(x) in temp_dict:
        temp_dict[ str(x) ]+=1
    else:
        temp_dict[ str(x) ] = 1
print("NN - hidden layers:")
print( temp_dict)
# Out:
# LR - best alpha = [0.01] with 94.
# RF - best n-estimat = [150] with 54.
# RF - best max-depth = [20] with 73.
# Keras - best lamda = [0.001] with 63
# NN - hidden layers:
# {'(500, 20, 10)': 34, '(100, 50)': 23, '50': 9, '(100, 20)': 44}

# %% [markdown]
# ### Cool info about coefficients by Lasso

# %%
# Coefficients by Lasso
Coef_LR = np.zeros(2048)
for model in LR_all:
    Coef_LR += LR_all[model].coef_
Coef_LR = Coef_LR/110  

indices_LR = []
ind = np.argsort(Coef_LR)
[indices_LR.append(x) for x in ind[:10] ]
[indices_LR.append(x) for x in ind[-10:] ]
print(indices_LR)

# Coefficients by RF
Coef_RF = np.zeros(2048)
for target in Targets:
    Coef_RF += RF_all[target].feature_importances_
Coef_RF = Coef_RF/110  

indices_RF = []
ind = np.argsort(Coef_RF)
[indices_RF.append(x) for x in ind[-20:] ]
print(indices_RF)
print("Common features:",'\t',[x for x in indices_LR if x in indices_RF])
# Out:
# [1057, 1607, 802, 1390, 598, 590, 232, 148, 345, 714, 3, 1672, 1674, 1639, 1826, 1394, 553, 715, 901, 1185]
# [857, 929, 1173, 19, 1379, 824, 1672, 9, 1863, 806, 1085, 835, 1009, 2039, 1556, 476, 792, 1339, 1915, 598]
# Common features: 	 [598, 1672]

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(221)
plt.plot( range(2048), Coef_LR, '.')
plt.plot( indices_LR, Coef_LR[indices_LR], 'rx')
plt.xlabel("Fingerprint Bit location",fontsize=13)
plt.ylabel("Aver. feature coefficient",fontsize=13)

ax1 = fig.add_subplot(222)
plt.plot( range(2048), Coef_RF, '.')
plt.plot( indices_RF, Coef_RF[indices_RF], 'rx')
plt.xlabel("Fingerprint Bit location",fontsize=13)
plt.ylabel("Aver. feature importance",fontsize=13)
plt.savefig("Lasso-bits_FCFP.png")
plt.show()

# %%
print("RMSE for RF = %f" % np.sqrt( MSE(True_vals, Pred_RF) ))
print("RMSE for NN = %f" % np.sqrt( MSE(True_vals, Pred_NN) ))
print("RMSE for LR = %f" % np.sqrt( MSE(True_vals, Pred_LR) ))
print("RMSE for Keras = %f" % np.sqrt( MSE(True_vals, Pred_my) ))

print(" MSE for RF = %f" % MSE(True_vals, Pred_RF) )
print(" MSE for NN = %f" % MSE(True_vals, Pred_NN) )
print(" MSE for LR = %f" % MSE(True_vals, Pred_LR) )
print(" MSE for Keras = %f" %MSE(True_vals, Pred_my))
# Out:
# RMSE for RF = 1.526617
# RMSE for NN = 1.731704
# RMSE for LR = 1.657303
# RMSE for Keras = 1.576179
#  MSE for RF = 2.330559
#  MSE for NN = 2.998797
#  MSE for LR = 2.746653
#  MSE for Keras = 2.484339

# %% [markdown]
# ### Some comparisons of distributions

# %%
# plt.figure()
plt.hist([t[0] for t in Pred_my],bins=20,color='m',alpha=0.9, label="Keras")

plt.hist([t[0] for t in Pred_RF],bins=20,color='r',label="RF")

plt.hist([t for t in True_vals],bins=20,color='y',alpha=0.6, label='true')
plt.legend(loc=1)
plt.show()
